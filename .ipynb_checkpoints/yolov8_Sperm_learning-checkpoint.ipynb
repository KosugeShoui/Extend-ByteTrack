# %% [markdown]
# # yolov8を精子のデータセットでFine tuning

# %%
cd ultralytics
# Out:
# /work/kosuge/M1/yolov8-learning/ultralytics

# %%
import os

path = os.getcwd()

print(path)
# Out:
# /work/kosuge/M1/yolov8-learning/ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# ## train
# - モデルの重み指定、degreeはデータ拡張、画像をランダムに0から90度回転させる
# - 結果はruns/detect/trainに保存

# %%
model = YOLO("yolov8n.pt")
model.train(data="../../Image_label/data_0512.yaml", epochs=500, batch=8, workers=0,name = 'train_1019_s_cj',patience = 200,
           dropout = 0.5)
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.8.10 torch-1.13.0+cu117 CUDA:0 (NVIDIA TITAN X (Pascal), 12194MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
# tensorboardの表示
# %load_ext tensorboard
# %tensorboard --logdir runs
